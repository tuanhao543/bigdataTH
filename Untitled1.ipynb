# %%
import pandas as pd
import pyreadr
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

rdata_file_path = 'C:/Users/A715-42G/Downloads/rdmTweets-201306.RData'


result = pyreadr.read_r(rdata_file_path)
df_rdata = result[None]


documents = df_rdata["your_column_name"].tolist()


count_vectorizer = CountVectorizer(stop_words="english")
sparse_matrix = count_vectorizer.fit_transform(documents)


doc_term_matrix = sparse_matrix.todense()


df = pd.DataFrame(
    doc_term_matrix,
    columns=count_vectorizer.get_feature_names_out(),
    index=df_rdata.index,
)


print(df)
print(cosine_similarity(df, df))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Error in setwd(workingDir): cannot change working directory
# Traceback:
#
# 1. setwd(workingDir)
